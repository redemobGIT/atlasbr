# %% [markdown]
# # 1. Census Data: Demographics & Income
#
# **The Problem:** Census data is usually trapped in massive FTP CSVs or complex SQL tables. Matching it to geometry (tracts) is painful.
#
# **The Solution:** AtlasBR unifies this into a single command.
#
# **What you will learn:**
# 1.  **Strategies:** How to switch between Cloud (BigQuery) and Online (FTP) modes seamlessly.
# 2.  **Harmonization:** Why `habitantes` is always `habitantes`, regardless of the source year.
# 3.  **Spatial Aggregation:** Using H3 Hexagons to fix irregular Census tracts.

# %% [markdown]
# # --- 1. Setup & Authentication ---

# %%
import os
import atlasbr
from atlasbr.app.census import load_census

atlasbr.configure_logging()

# %%
project_id = os.getenv("GOOGLE_CLOUD_PROJECT") or os.getenv("GCLOUD_PROJECT_ID")

MUNICIPALITY = "Rio de Janeiro, RJ"

# %% [markdown]
# # 2. The Cloud Strategy (BigQuery)
# *Best for: Speed, low memory usage, and querying specific subsets.*
#
# We fetch data directly from the Data Lake. Note that we request specific **themes** (`basic`, `income`). AtlasBR knows exactly which tables to join.

# %%
gdf_cloud = load_census(
    places=[MUNICIPALITY],
    year=2022,
    themes=["basic", "income", "age", "race"],
    strategy="bd",
    geometry="h3"
)
print(f"✅ Loaded {len(gdf_cloud)} tracts from BigQuery.")
# Out:
# 2026-01-29 15:02:29,690 - atlasbr - INFO -     ℹ️  Resolved 'Rio de Janeiro, RJ' -> 3304557
# 2026-01-29 15:02:29,692 - atlasbr - INFO -     📦 Loading theme: 'basic' via bd...
# 2026-01-29 15:02:29,694 - atlasbr - INFO -     ☁️  Querying Base dos Dados (basic 2022)...
# Downloading: 100%|██████████|
# 2026-01-29 15:02:31,933 - atlasbr - INFO -     📦 Loading theme: 'income' via bd...
# 2026-01-29 15:02:31,934 - atlasbr - INFO -     ⬇️  Fetching income (BR) from IBGE FTP...
# 2026-01-29 15:02:32,984 - atlasbr - INFO -     📦 Loading theme: 'age' via bd...
# 2026-01-29 15:02:32,986 - atlasbr - INFO -     ☁️  Querying Base dos Dados (age 2022)...
# Downloading: 100%|██████████|
# 2026-01-29 15:02:37,679 - atlasbr - INFO -     📦 Loading theme: 'race' via bd...
# 2026-01-29 15:02:37,680 - atlasbr - INFO -     ☁️  Querying Base dos Dados (race 2022)...
# Downloading: 100%|██████████|
# 2026-01-29 15:02:53,207 - atlasbr - INFO -     🗺️  Fetching Tract Geometries...
# 2026-01-29 15:02:53,208 - atlasbr - INFO - Fetching Census Tracts for 1 municipalities (Year 2022)...
# 2026-01-29 15:02:53,824 - atlasbr - INFO -     ⬢ Aggregating to H3 resolution 8...
# ✅ Loaded 1585 tracts from BigQuery.

# %%
gdf_cloud.sample(3)
# Out:
#                                                           geometry  \
# h3_index
# 88a8a061a9fffff  POLYGON ((677820.847 7470090.575, 677733.316 7...
# 88a8a07ab7fffff  POLYGON ((682427.213 7457198.224, 682339.89 74...
# 88a8a07689fffff  POLYGON ((650808.373 7454293.045, 650720.249 7...
#
#                    habitantes   domicilios     age_0_14   age_15_19  \
# h3_index
# 88a8a061a9fffff   8144.770120  3627.287881  1502.427074  598.564788
# 88a8a07ab7fffff  12510.488806  7175.228010  1384.709226  443.581522
# 88a8a07689fffff     78.616005    40.521570    13.733923    5.493058
#
#                    age_20_64      age_65p   cor_branca    cor_preta  \
# h3_index
# 88a8a061a9fffff  5011.632616  1032.145642  2924.920026  1618.933253
# 88a8a07ab7fffff  7041.692845  3640.505214  8294.031073   939.399585
# 88a8a07689fffff    47.618219    11.770804    31.276870     7.628015
#
#                  cor_amarela    cor_parda  cor_indigena  \
# h3_index
# 88a8a061a9fffff     0.192842  3182.512739      0.036468
# 88a8a07ab7fffff     2.723637  1580.209184      0.033611
# 88a8a07689fffff     0.001763    35.118753      0.000333
#
#                  rendimento_medio_responsaveis
# h3_index
# 88a8a061a9fffff                    2324.042049
# 88a8a07ab7fffff                   14244.194213
# 88a8a07689fffff                     390.835900

# %%
gdf_cloud.explore('rendimento_medio_responsaveis')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_279e9f100c007d1cd3998e67ec3ad8fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_279e9f100c007d1cd3998e67ec3ad8fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_279e9f100c007d1cd3998e67ec3ad8fe = L.map(
#                 &quot;map_279e9f100c007d1cd3998e67ec3ad8fe&quot;,
#                 {
#                     center: [-22.92581921133666, -43.46895685749457],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_279e9f100c007d1cd3998e67ec3ad8fe);
#
#
#
#
#
#             var tile_layer_b1db4253a88b0bff750d5fc818bfe106 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1db4253a88b0bff750d5fc818bfe106.addTo(map_279e9f100c007d1cd3998e67ec3ad8fe);
#
#
#             map_279e9f100c007d1cd3998e67ec3ad8fe.fitBounds(
#                 [[-23.075642600000002, -43.7955461], [-22.77599582267332, -43.14236761498913]],
#                 {}
#             );
#
#
#         function geo_json_26fd9c587e7c2e1d8667e22b2ee66434_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;177&quot;: case &quot;244&quot;: case &quot;293&quot;: case &quot;346&quot;: case &quot;361&quot;: case &quot;386&quot;: case &quot;418&quot;: case &quot;521&quot;: case &quot;678&quot;: case &quot;723&quot;: case &quot;953&quot;: case &quot;1281&quot;: case &quot;1308&quot;: case &quot;1332&quot;: case &quot;1358&quot;: case &quot;1485&quot;: case &quot;1581&quot;:
#                     return {&quot;color&quot;: &quot;#481d6f&quot;, &quot;fillColor&quot;: &quot;#481d6f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;25&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;65&quot;: case &quot;66&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;77&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;85&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;107&quot;: case &quot;108&quot;: case &quot;109&quot;: case &quot;110&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;113&quot;: case &quot;114&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;123&quot;: case &quot;127&quot;: case &quot;146&quot;: case &quot;236&quot;: case &quot;237&quot;: case &quot;239&quot;: case &quot;242&quot;: case &quot;243&quot;: case &quot;250&quot;: case &quot;251&quot;: case &quot;254&quot;: case &quot;262&quot;: case &quot;317&quot;: case &quot;321&quot;: case &quot;333&quot;: case &quot;335&quot;: case &quot;337&quot;: case &quot;350&quot;: case &quot;352&quot;: case &quot;354&quot;: case &quot;356&quot;: case &quot;358&quot;: case &quot;370&quot;: case &quot;371&quot;: case &quot;372&quot;: case &quot;374&quot;: case &quot;376&quot;: case &quot;378&quot;: case &quot;390&quot;: case &quot;391&quot;: case &quot;393&quot;: case &quot;394&quot;: case &quot;395&quot;: case &quot;396&quot;: case &quot;397&quot;: case &quot;399&quot;: case &quot;404&quot;: case &quot;408&quot;: case &quot;411&quot;: case &quot;412&quot;: case &quot;415&quot;: case &quot;416&quot;: case &quot;420&quot;: case &quot;421&quot;: case &quot;422&quot;

# %% [markdown]
# # 3. The FTP Strategy
# *Best for: Users without cloud credentials.*
#
# Change `strategy="ftp_csv"`. AtlasBR will:
# 1.  Download the official ZIPs from IBGE (cached locally).
# 2.  Extract and parse the CSVs.
# 3.  **Rename columns** to match the BigQuery schema exactly.

# %%
gdf_ftp = load_census(
    places=[MUNICIPALITY],
    year=2010, # AtlasBR automatically finds the 2010 FTP URLs
    themes=["basic", "race"],
    strategy="ftp",
    geometry="tract"
)

# PROOF: The schemas are identical.
# You can write your analysis code once, and it runs on both backends.
print("Columns match?", set(gdf_ftp.columns) == set(gdf_cloud.columns) if 'gdf_cloud' in locals() else "Skipped Cloud")
display(gdf_ftp.head())

# %% [markdown]
# # 4. Solving the "MAUP" with H3
# **The Problem:** Census tracts vary wildly in size. Some are tiny city blocks; others are massive rural areas. This distorts maps (visual bias).
#
# **The Solution:** We aggregate data to a regular **H3 Hexagonal Grid**.
# * **Extensive vars** (Population) are redistributed by area.
# * **Intensive vars** (Income) are averaged.

# %%
gdf_hex = load_census(
    places=[MUNICIPALITY],
    year=2022,
    themes=["age"],
    strategy="ftp", # Using FTP to ensure it runs for everyone
    geometry="h3",      # <--- The Magic Switch
    h3_res=9            # Resolution 9 (~0.1 km² per hex)
)

print(f"⬢ Transformed {len(gdf_ftp)} irregular tracts into {len(gdf_hex)} regular hexagons.")

# %% [markdown]
# # 5. Interactive Exploration
# Notice how the hexagons reveal density patterns that irregular tracts might hide.

# %%
# Explore Income Distribution
gdf_hex.explore(
    column="rendimento_medio_responsaveis",
    cmap="magma",
    tiles="CartoDB DarkMatter",
    tooltip=["h3_index", "habitantes", "rendimento_medio_responsaveis"],
    style_kwds={"fillOpacity": 0.6, "weight": 0},
    legend_kwds={"caption": "Average Income (R$)"}
)

# %%
gdf_hex
