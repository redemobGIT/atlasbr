# %% [markdown]
# # 1. Census Data: Demographics & Income
#
# **The Problem:** Census data is usually trapped in massive FTP CSVs or complex SQL tables. Matching it to geometry (tracts) is painful.
#
# **The Solution:** AtlasBR unifies this into a single command.
#
# **What you will learn:**
# 1.  **Strategies:** How to switch between Cloud (BigQuery) and Online (FTP) modes seamlessly.
# 2.  **Harmonization:** Why `habitantes` is always `habitantes`, regardless of the source year.
# 3.  **Spatial Aggregation:** Using H3 Hexagons to fix irregular Census tracts.

# %% [markdown]
# # --- 1. Setup & Authentication ---

# %%
import sys
import os
from pathlib import Path

# --- DEVELOPER SETUP (Optional) ---
# If running locally without 'pip install', we add the '../src' folder to path.
current_path = Path(os.getcwd())
if current_path.name == "tutorials":
    # Go up one level to root, then into 'src' (if using src-layout) or just root (flat-layout)
    root_dir = current_path.parent
    src_dir = root_dir / "src"
    
    if src_dir.exists():
        sys.path.append(str(src_dir))
    else:
        sys.path.append(str(root_dir))

import atlasbr

# %%
from atlasbr.app.census import load_census

# VISUAL TIP: We use logging to show you exactly what's happening under the hood.
atlasbr.configure_logging()

# CREDENTIALS CHECK:
project_id = os.getenv("GOOGLE_CLOUD_PROJECT") or os.getenv("GCLOUD_PROJECT_ID")
if not project_id:
    print("⚠️  Warning: No Google Cloud credentials found. We will demonstrate the FTP strategy.")

# %%
MUNICIPALITY = "Rio de Janeiro, RJ"

# %% [markdown]
# # 2. The Cloud Strategy (BigQuery)
# *Best for: Speed, low memory usage, and querying specific subsets.*
#
# We fetch data directly from the Data Lake. Note that we request specific **themes** (`basic`, `income`). AtlasBR knows exactly which tables to join.

# %% [raw]
# try:
#     gdf_cloud = load_census(
#         places=[MUNICIPALITY],
#         year=2010,
#         themes=["basic", "income"],
#         strategy="bd",
#         geometry="tract"
#     )
#     print(f"✅ Loaded {len(gdf_cloud)} tracts from BigQuery.")
#
#     # Let's see the standardized columns
#     display(gdf_cloud[["habitantes", "domicilios", "rendimento_medio"]].head())
#
# except Exception as e:
#     print(f"❌ Cloud load skipped: {e}")

# %% [markdown]
# # 3. The FTP Strategy
# *Best for: Users without cloud credentials.*
#
# Change `strategy="ftp_csv"`. AtlasBR will:
# 1.  Download the official ZIPs from IBGE (cached locally).
# 2.  Extract and parse the CSVs.
# 3.  **Rename columns** to match the BigQuery schema exactly.

# %%
gdf_ftp = load_census(
    places=[MUNICIPALITY],
    year=2010, # AtlasBR automatically finds the 2010 FTP URLs
    themes=["basic", "race"],
    strategy="ftp",
    geometry="tract"
)

# PROOF: The schemas are identical.
# You can write your analysis code once, and it runs on both backends.
print("Columns match?", set(gdf_ftp.columns) == set(gdf_cloud.columns) if 'gdf_cloud' in locals() else "Skipped Cloud")
display(gdf_ftp.head())
# Out:
# 2025-12-17 23:15:35,520 - atlasbr - INFO -     🌍 Fetching municipality metadata from geobr...
# 2025-12-17 23:15:36,266 - atlasbr - INFO -     ℹ️  Resolved 'Rio de Janeiro, RJ' -> 3304557
# 2025-12-17 23:15:36,268 - atlasbr - INFO -     📦 Loading theme: 'basic' via ftp_csv...
# 2025-12-17 23:15:36,277 - atlasbr - INFO -     ⬇️  Fetching basic (RJ) from IBGE FTP...
# 2025-12-17 23:15:36,793 - atlasbr - INFO -     📦 Loading theme: 'race' via ftp_csv...
# 2025-12-17 23:15:36,795 - atlasbr - INFO -     ⬇️  Fetching race (RJ) from IBGE FTP...
# 2025-12-17 23:15:37,393 - atlasbr - INFO -     🗺️  Fetching Tract Geometries...
# 2025-12-17 23:15:37,394 - atlasbr - INFO - Fetching Census Tracts for 1 municipalities (Year 2010)...
# Columns match? Skipped Cloud
#                                                               geometry  \
# id_setor_censitario
# 330455705080006      MULTIPOLYGON (((684642.967 7463703.496, 684639...
# 330455705080007      MULTIPOLYGON (((684809.547 7464393.366, 684784...
# 330455705080008      MULTIPOLYGON (((684744.206 7464342.099, 684713...
# 330455705080009      MULTIPOLYGON (((684721.539 7464274.631, 684721...
# 330455705080010      MULTIPOLYGON (((684810.966 7464172.912, 684810...
#
#                      habitantes  cor_branca  cor_preta  cor_amarela  \
# id_setor_censitario
# 330455705080006           410.0       152.0      178.0          0.0
# 330455705080007           444.0       187.0       48.0         17.0
# 330455705080008           505.0       177.0       92.0          6.0
# 330455705080009           430.0       251.0       38.0          1.0
# 330455705080010           372.0        89.0       83.0          8.0
#
#                      cor_parda  cor_indigena
# id_setor_censitario
# 330455705080006           80.0           0.0
# 330455705080007          191.0           1.0
# 330455705080008          230.0           0.0
# 330455705080009          153.0           0.0
# 330455705080010          192.0           0.0

# %% [markdown]
# # 4. Solving the "MAUP" with H3
# **The Problem:** Census tracts vary wildly in size. Some are tiny city blocks; others are massive rural areas. This distorts maps (visual bias).
#
# **The Solution:** We aggregate data to a regular **H3 Hexagonal Grid**.
# * **Extensive vars** (Population) are redistributed by area.
# * **Intensive vars** (Income) are averaged.

# %%
gdf_hex = load_census(
    places=[MUNICIPALITY],
    year=2022,
    themes=["age"],
    strategy="ftp", # Using FTP to ensure it runs for everyone
    geometry="h3",      # <--- The Magic Switch
    h3_res=9            # Resolution 9 (~0.1 km² per hex)
)

print(f"⬢ Transformed {len(gdf_ftp)} irregular tracts into {len(gdf_hex)} regular hexagons.")
# Out:
# 2025-12-17 23:15:40,620 - atlasbr - INFO -     ℹ️  Resolved 'Rio de Janeiro, RJ' -> 3304557
# 2025-12-17 23:15:40,623 - atlasbr - INFO -     📦 Loading theme: 'age' via ftp_csv...
# 2025-12-17 23:15:40,625 - atlasbr - INFO -     ⬇️  Fetching age (BR) from IBGE FTP...
# 2025-12-17 23:15:56,060 - atlasbr - INFO -     🗺️  Fetching Tract Geometries...
# 2025-12-17 23:15:56,062 - atlasbr - INFO - Fetching Census Tracts for 1 municipalities (Year 2022)...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 gdf_hex = load_census(
#       2     places=[MUNICIPALITY],
#       3     year=2022,
#       4     themes=["age"],
#       5     strategy="ftp_csv", # Using FTP to ensure it runs for everyone
#       6     geometry="h3",      # <--- The Magic Switch
#       7     h3_res=9            # Resolution 9 (~0.1 km² per hex)
#       8 )
#      10 print(f"⬢ Transformed {len(gdf_ftp)} irregular tracts into {len(gdf_hex)} regular hexagons.")
#
# File c:\Users\brand\OneDrive\Documentos\GitHub\atlasbr\src\atlasbr\app\census.py:147, in load_census(places, year, themes, strategy, geometry, h3_res, gcp_billing, clip_urban)
#     144 final_rows = len(gdf_data)
#     146 if final_rows == 0:
# --> 147     raise RuntimeError(
#     148         "Intersection of Census Data and Geometries is empty. "
#     149         "Check if year/municipality codes align."
#     150     )
#     152 if final_rows < initial_rows:
#     153     dropped = initial_rows - final_rows
#
# RuntimeError: Intersection of Census Data and Geometries is empty. Check if year/municipality codes align.

# %% [markdown]
# # 5. Interactive Exploration
# Notice how the hexagons reveal density patterns that irregular tracts might hide.

# %%
# Explore Income Distribution
gdf_hex.explore(
    column="rendimento_medio_responsaveis",
    cmap="magma",
    tiles="CartoDB DarkMatter",
    tooltip=["h3_index", "habitantes", "rendimento_medio_responsaveis"],
    style_kwds={"fillOpacity": 0.6, "weight": 0},
    legend_kwds={"caption": "Average Income (R$)"}
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\brand\anaconda3\envs\roda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rendimento_medio_responsaveis'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Explore Income Distribution
# ----> 2 gdf_hex.explore(
#       3     column="rendimento_medio_responsaveis",
#       4     cmap="magma",
#       5     tiles="CartoDB DarkMatter",
#       6     tooltip=["h3_index", "habitantes", "rendimento_medio_responsaveis"],
#       7     style_kwds={"fillOpacity": 0.6, "weight": 0},
#       8     legend_kwds={"caption": "Average Income (R$)"}
#       9 )
#
# File c:\Users\brand\anaconda3\envs\roda\Lib\site-packages\geopandas\geodataframe.py:2305, in GeoDataFrame.explore(self, *args, **kwargs)
#    2303 @doc(_explore)
#    2304 def explore(self, *args, **kwargs):
# -> 2305     return _explore(self, *args, **kwargs)
#
# File c:\Users\brand\anaconda3\envs\roda\Lib\site-packages\geopandas\explore.py:427, in _explore(df, column, cmap, color, m, tiles, attr, tooltip, popup, highlight, categorical, legend, scheme, k, vmin, vmax, width, height, categories, classification_kwds, control_scale, marker_type, marker_kwds, style_kwds, highlight_kwds, missing_kwds, tooltip_kwds, popup_kwds, legend_kwds, map_kwds, **kwargs)
#     425         gdf[column_name] = column
#     426         column = column_name
# --> 427 elif isinstance(gdf[column].dtype, pd.CategoricalDtype):
#     428     if categories is not None:
#     429         raise ValueError(
#     430             "Cannot specify 'categories' when column has categorical dtype"
#     431         )
#
# File c:\Users\brand\anaconda3\envs\roda\Lib\site-packages\geopandas\geodataframe.py:1750, in GeoDataFrame.__getitem__(self, key)
#    1744 def __getitem__(self, key):
#    1745     """
#    1746     If the result is a column containing only 'geometry', return a
#    1747     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1748     return a GeoDataFrame.
#    1749     """
# -> 1750     result = super().__getitem__(key)
#    1751     # Custom logic to avoid waiting for pandas GH51895
#    1752     # result is not geometry dtype for multi-indexes
#    1753     if (
#    1754         pd.api.types.is_scalar(key)
#    1755         and key == ""
#    (...)   1758         and not is_geometry_type(result)
#    1759     ):
#
# File c:\Users\brand\anaconda3\envs\roda\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\brand\anaconda3\envs\roda\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'rendimento_medio_responsaveis'

# %%
gdf_hex
# Out:
#                                                           geometry  \
# h3_index
# 89a8a0395d7ffff  POLYGON ((647018.891 7447576.778, 647129.325 7...
# 89a8a0395c3ffff  POLYGON ((647438.367 7447560.641, 647339.066 7...
# 89a8a03958bffff  POLYGON ((646709.846 7447760.154, 646820.279 7...
# 89a8a0395cbffff  POLYGON ((647758.547 7447719.811, 647659.247 7...
# 89a8a0395c7ffff  POLYGON ((647129.325 7447744.017, 647030.02 74...
# ...                                                            ...
# 89a8a06e313ffff  POLYGON ((672059.773 7477019.208, 671960.491 7...
# 89a8a06e353ffff  POLYGON ((673011.102 7477154.846, 672911.827 7...
# 89a8a06e31bffff  POLYGON ((672701.702 7477338.75, 672590.856 74...
# 89a8a06e317ffff  POLYGON ((672071.331 7477362.881, 671960.491 7...
# 89a8a06e357ffff  POLYGON ((673022.676 7477498.527, 672911.827 7...
#
#                   habitantes  domicilios     age_0_14  age_15_19  age_20_64  \
# h3_index
# 89a8a0395d7ffff     0.000000    0.000000     0.000000        0.0        0.0
# 89a8a0395c3ffff     0.000000    0.000000     0.000000        0.0        0.0
# 89a8a03958bffff   156.738838  132.083291   156.738838        0.0        0.0
# 89a8a0395cbffff     0.000000    0.000000     0.000000        0.0        0.0
# 89a8a0395c7ffff     0.595888    0.502153     0.595888        0.0        0.0
# ...                      ...         ...          ...        ...        ...
# 89a8a06e313ffff  1532.342528  748.699266  1532.342528        0.0        0.0
# 89a8a06e353ffff   852.596991  318.582354   852.596991        0.0        0.0
# 89a8a06e31bffff  1945.006768  777.433733  1945.006768        0.0        0.0
# 89a8a06e317ffff  1994.021831  852.230765  1994.021831        0.0        0.0
# 89a8a06e357ffff   894.492364  345.043951   894.492364        0.0        0.0
#
#                  age_65p  habitantes  domicilios  \
# h3_index
# 89a8a0395d7ffff      0.0    0.000000    0.000000
# 89a8a0395c3ffff      0.0    0.000000    0.000000
# 89a8a03958bffff      0.0  157.010705  132.312392
# 89a8a0395cbffff      0.0    0.000000    0.000000
# 89a8a0395c7ffff      0.0    0.593155    0.499850
# ...                  ...         ...         ...
# 89a8a06e313ffff      0.0  378.285658  187.431665
# 89a8a06e353ffff      0.0  288.278997  107.951171
# 89a8a06e31bffff      0.0  792.489780  315.606536
# 89a8a06e317ffff      0.0  530.151219  238.626899
# 89a8a06e357ffff      0.0  686.631267  266.652212
#
#                  rendimento_medio_responsaveis
# h3_index
# 89a8a0395d7ffff                       0.000000
# 89a8a0395c3ffff                       0.000000
# 89a8a03958bffff                    2054.640907
# 89a8a0395cbffff                       0.000000
# 89a8a0395c7ffff                       7.762020
# ...                                        ...
# 89a8a06e313ffff                    2068.710592
# 89a8a06e353ffff                     468.154180
# 89a8a06e31bffff                    1244.602410
# 89a8a06e317ffff                    1902.811330
# 89a8a06e357ffff                    1041.526641
#
# [11082 rows x 10 columns]
