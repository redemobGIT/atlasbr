# %% [markdown]
# # Título do Projeto

# %% [markdown]
# ## 1. Configurações de ambiente

# %%
import sys
import os

# Add the project's root directory to the Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
# 1. Standard library
from functools import lru_cache
from io import BytesIO
import gc
import json
import os
from pathlib import Path
import re
import requests
from typing import Any, Dict, Iterable, List, Optional, Tuple
import tempfile
import zipfile

# 2. Third-party
import basedosdados as bd
from dotenv import load_dotenv
import geopandas as gpd
import geobr
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pandas as pd
import plotly.express.colors as colors  
import plotly.graph_objects as go
import seaborn as sns
from statsmodels.stats.weightstats import DescrStatsW
from tobler.area_weighted import area_interpolate
from tobler.util import h3fy

# 3. Local Application Modules
from config import GCLOUD_PROJECT_ID
from src.roda.fetch_data.urban_area import get_urban_area_gdf
from src.roda.utils.helpers import get_municipality_codes_from_names

# %% [markdown]
# ## 2.

# %% [markdown]
# ##### TESTES

# %%
cities = [("RJ", "Rio de Janeiro"), ("RJ", "Niterói")]
muni_codes = get_municipality_codes_from_names(cities=cities)
print(muni_codes)
# Out:
# [3304557, 3303302]

# %%
x = get_urban_area_gdf(2005)
x.head(5)
# Out:
# 🛰️  Selected epoch 2005 for year 2005. Downloading from: areas_urbanizadas_do_Brasil_2005_shapes.zip
#           Tipo GEOCODIGO    GEOC_URB  POP_2005 NOME_MUNIC  UF  Area_Km2  \
# 0        Densa   1100122  1100122001  112439.0  Ji-Paraná  RO      0.99
# 1        Densa   1100122  1100122002  112439.0  Ji-Paraná  RO      9.69
# 2        Densa   1100122  1100122003  112439.0  Ji-Paraná  RO     14.84
# 3  Pouco densa   1100122  1100122004  112439.0  Ji-Paraná  RO      0.53
# 4  Pouco densa   1100122  1100122005  112439.0  Ji-Paraná  RO      0.80
#
#                                             geometry
# 0  POLYGON ((-61.9667 -10.8565, -61.96661 -10.857...
# 1  POLYGON ((-61.97096 -10.89053, -61.97128 -10.8...
# 2  POLYGON ((-61.89986 -10.86867, -61.90041 -10.8...
# 3  POLYGON ((-62.00899 -11.06986, -62.0091 -11.07...
# 4  POLYGON ((-61.68801 -10.79494, -61.69343 -10.7...
